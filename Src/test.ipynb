# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 50;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [(1, datetime.datetime(2018, 11, 21, 0, 57, 58, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2, datetime.datetime(2018, 11, 21, 0, 58, 41, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (3, datetime.datetime(2018, 11, 21, 1, 2, 5, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (4, datetime.datetime(2018, 11, 21, 1, 3, 13, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (5, datetime.datetime(2018, 11, 21, 1, 5, 29, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (6, datetime.datetime(2018, 11, 21, 1, 9, 37, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (7, datetime.datetime(2018, 11, 21, 1, 13, 22, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (8, datetime.datetime(2018, 11, 21, 1, 16, 52, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (9, datetime.datetime(2018, 11, 21, 1, 20, 24, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (10, datetime.datetime(2018, 11, 21, 1, 24, 3, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (11, datetime.datetime(2018, 11, 21, 1, 27, 34, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (12, datetime.datetime(2018, 11, 21, 1, 43, 47, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (13, datetime.datetime(2018, 11, 21, 1, 44, 43, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (14, datetime.datetime(2018, 11, 21, 1, 47, 20, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (15, datetime.datetime(2018, 11, 21, 1, 48, 56, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (16, datetime.datetime(2018, 11, 21, 1, 52, 58, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (17, datetime.datetime(2018, 11, 21, 1, 53, 49, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (18, datetime.datetime(2018, 11, 21, 1, 57, 34, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (19, datetime.datetime(2018, 11, 21, 1, 58, 33, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (20, datetime.datetime(2018, 11, 21, 2, 1, 1, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (21, datetime.datetime(2018, 11, 21, 2, 1, 44, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (22, datetime.datetime(2018, 11, 21, 2, 4, 56, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (23, datetime.datetime(2018, 11, 21, 2, 8, 7, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (24, datetime.datetime(2018, 11, 21, 2, 8, 8, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (25, datetime.datetime(2018, 11, 21, 2, 12, 9, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (26, datetime.datetime(2018, 11, 21, 2, 12, 57, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (27, datetime.datetime(2018, 11, 21, 2, 16, 8, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (28, datetime.datetime(2018, 11, 21, 2, 16, 18, 796000), 97, 'paid', None, None, 671, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (29, datetime.datetime(2018, 11, 21, 2, 18, 40, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (30, datetime.datetime(2018, 11, 21, 2, 29, 35, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (31, datetime.datetime(2018, 11, 21, 2, 31, 6, 796000), 40, 'free', None, None, 784, 'Oxnard-Thousand Oaks-Ventura, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (32, datetime.datetime(2018, 11, 21, 2, 34, 45, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (33, datetime.datetime(2018, 11, 21, 2, 39, 34, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (34, datetime.datetime(2018, 11, 21, 2, 47, 9, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (35, datetime.datetime(2018, 11, 21, 2, 55, 7, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (36, datetime.datetime(2018, 11, 21, 2, 59, 53, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (37, datetime.datetime(2018, 11, 21, 3, 5, 23, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (38, datetime.datetime(2018, 11, 21, 3, 8, 38, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (39, datetime.datetime(2018, 11, 21, 3, 12, 22, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (40, datetime.datetime(2018, 11, 21, 3, 16, 43, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (41, datetime.datetime(2018, 11, 21, 3, 17, 55, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (42, datetime.datetime(2018, 11, 21, 3, 21, 56, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (43, datetime.datetime(2018, 11, 21, 3, 25, 41, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (44, datetime.datetime(2018, 11, 21, 3, 28, 40, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (45, datetime.datetime(2018, 11, 21, 3, 31, 42, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (46, datetime.datetime(2018, 11, 21, 3, 34, 27, 796000), 97, 'paid', None, None, 797, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (47, datetime.datetime(2018, 11, 21, 3, 35, 17, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (48, datetime.datetime(2018, 11, 21, 3, 39, 23, 796000), 97, 'paid', None, None, 797, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (49, datetime.datetime(2018, 11, 21, 3, 39, 46, 796000), 80, 'paid', None, None, 774, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (50, datetime.datetime(2018, 11, 21, 3, 42, 23, 796000), 97, 'paid', None, None, 797, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 50;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [(65, 'Amiya', 'Davidson', 'F', 'paid'),
#  (5, 'Elijah', 'Davis', 'M', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free'),
#  (38, 'Gianna', 'Jones', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (63, 'Ayla', 'Johnson', 'F', 'free'),
#  (11, 'Christian', 'Porter', 'F', 'free'),
#  (30, 'Avery', 'Watkins', 'F', 'paid'),
#  (91, 'Jayden', 'Bell', 'M', 'free'),
#  (100, 'Adler', 'Barrera', 'M', 'free'),
#  (23, 'Morris', 'Gilmore', 'M', 'free'),
#  (97, 'Kate', 'Harrell', 'F', 'paid'),
#  (40, 'Tucker', 'Garrison', 'M', 'free'),
#  (18, 'Jacob', 'Rogers', 'M', 'free'),
#  (72, 'Hayden', 'Brock', 'F', 'paid'),
#  (59, 'Lily', 'Cooper', 'F', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (98, 'Jordyn', 'Powell', 'F', 'free'),
#  (56, 'Cienna', 'Freeman', 'F', 'free'),
#  (94, 'Noah', 'Chavez', 'M', 'free'),
#  (70, 'Jaleah', 'Hayes', 'F', 'paid'),
#  (76, 'Jayden', 'Duffy', 'F', 'free'),
#  (9, 'Wyatt', 'Scott', 'M', 'free'),
#  (20, 'Aiden', 'Ramirez', 'M', 'paid'),
#  (37, 'Jordan', 'Hicks', 'F', 'free'),
#  (28, 'Brantley', 'West', 'M', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (77, 'Magdalene', 'Herman', 'F', 'free'),
#  (81, 'Sienna', 'Colon', 'F', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (41, 'Brayden', 'Clark', 'M', 'free'),
#  (45, 'Dominick', 'Norris', 'M', 'free'),
#  (79, 'James', 'Martin', 'M', 'free'),
#  (64, 'Hannah', 'Calhoun', 'F', 'free'),
#  (82, 'Avery', 'Martinez', 'F', 'paid'),
#  (34, 'Evelin', 'Ayala', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (62, 'Connar', 'Moreno', 'M', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (35, 'Molly', 'Taylor', 'F', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (78, 'Chloe', 'Roth', 'F', 'free'),
#  (74, 'Braden', 'Parker', 'M', 'free'),
#  (39, 'Walter', 'Frye', 'M', 'free'),
#  (71, 'Ayleen', 'Wise', 'F', 'free'),
#  (95, 'Sara', 'Johnson', 'F', 'paid'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (42, 'Harper', 'Barrett', 'M', 'paid'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (14, 'Theodore', 'Harris', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 335.51628),
#  ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326.00771),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282.43546),
#  ('SOLYIBD12A8C135045', 'Music is what we love', 'AR051KA1187B98B2FF', 0, 261.51138),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 290.55955)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARULZCI1241B9C8611', 'Luna Orbit Project', '', nan, nan),
#  ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', 32.74863, -97.32925),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', -13.442, -41.9952),
#  ('AR051KA1187B98B2FF', 'Wilks', '', nan, nan),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', nan, nan)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 21, 0, 57, 58, 796000), 0, 21, 47, 11, 2018, 2),
#  (datetime.datetime(2018, 11, 21, 0, 58, 41, 796000), 0, 21, 47, 11, 2018, 2),
#  (datetime.datetime(2018, 11, 21, 1, 2, 5, 796000), 1, 21, 47, 11, 2018, 2),
#  (datetime.datetime(2018, 11, 21, 1, 3, 13, 796000), 1, 21, 47, 11, 2018, 2),
#  (datetime.datetime(2018, 11, 21, 1, 5, 29, 796000), 1, 21, 47, 11, 2018, 2)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
